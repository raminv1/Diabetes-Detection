# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv(r"diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ###### We can see that there are no null values

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ###### From above code we can check the datatype for each columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)
plt.figure(figsize = (10,7))
sns.heatmap(df.corr(), annot=True, cmap="Reds")
plt.title('Absolute Pearson Correlation between Different Features')
# Out:
# C:\Users\psair\AppData\Local\Temp\ipykernel_9048\4127760419.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")
# Text(0.5, 1.0, 'Absolute Pearson Correlation between Different Features')

# %% [markdown]
# ###### From above heat diagram we can Age and Pregnancies as best correlation values which is 0.54. And the 2nd best is between Outcome and Pregnancies which is around 0.47

# %%
#selecting target variables
X = df.drop('Outcome', axis=1)
y = df['Outcome']
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ###### we are trying to import KNN classifier from sklearn

# %%
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
pred = knn.predict(X_test)
labels = sorted(list(set(y_test)))
cm = confusion_matrix(y_test, pred, labels=labels)
ax = sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       107
#            1       0.73      0.51      0.60        47
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.78      0.79      0.78       154

# %% [markdown]
# ###### From above classification model we can see,accuracy of f1 score is around 79%, macro avg is 73% amd weighted avg is 78%.which is best when compared to other models.

# %%
p = df.hist(figsize = (20,20))

# %% [markdown]
# ###### Above Visualization we can see histgram for every column.

# %% [markdown]
# # this is 2nd model svm

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# SVC()

# %%
pred = svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[98  9]
#  [23 24]]

# %%
pred = svc.predict(X_test)
labels = sorted(list(set(y_test)))
cm = confusion_matrix(y_test, pred, labels=labels)
ax = sns.heatmap(cm, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86       107
#            1       0.73      0.51      0.60        47
#
#     accuracy                           0.79       154
#    macro avg       0.77      0.71      0.73       154
# weighted avg       0.78      0.79      0.78       154

# %% [markdown]
# ###### From above classification model we can see,accuracy of f1 score is around 79%, macro avg is 73% amd weighted avg is 78%.which is Similar to 1st model(KNN).

# %% [markdown]
# # this is 3rd model Keras Classification

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
#Ref. for adding layers and number of neurons 
#31 features + 1 for bias 
model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))
#model.add(Dense(8,activation='relu'))

model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=600)
# Out:
# Epoch 1/600
# 20/20 [==============================] - 2s 24ms/step - loss: 0.6808 - val_loss: 0.6556
# Epoch 2/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6685 - val_loss: 0.6410
# Epoch 3/600
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6598 - val_loss: 0.6281
# Epoch 4/600
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6544 - val_loss: 0.6221
# Epoch 5/600
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6493 - val_loss: 0.6188
# Epoch 6/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6446 - val_loss: 0.6126
# Epoch 7/600
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6395 - val_loss: 0.6045
# Epoch 8/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6314 - val_loss: 0.5847
# Epoch 9/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6206 - val_loss: 0.5791
# Epoch 10/600
# ...

# %%
loss = pd.DataFrame(model.history.history)
loss.head()
# Out:
#        loss  val_loss
# 0  0.680837  0.655603
# 1  0.668454  0.641023
# 2  0.659830  0.628086
# 3  0.654441  0.622068
# 4  0.649323  0.618799

# %%
loss.plot()
# Out:
# <Axes: >

# %%
model = Sequential() 

model.add(Dense(32,activation='relu'))
model.add(Dense(16,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
earlystop = EarlyStopping(monitor='val_loss',mode='min',patience=20)

# %%
model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          epochs=600, 
          callbacks=[earlystop])
# Out:
# Epoch 1/600
# 20/20 [==============================] - 2s 18ms/step - loss: 0.6789 - val_loss: 0.6547
# Epoch 2/600
# 20/20 [==============================] - 0s 8ms/step - loss: 0.6704 - val_loss: 0.6444
# Epoch 3/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6625 - val_loss: 0.6338
# Epoch 4/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6547 - val_loss: 0.6222
# Epoch 5/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6465 - val_loss: 0.6115
# Epoch 6/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6384 - val_loss: 0.6011
# Epoch 7/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6277 - val_loss: 0.5917
# Epoch 8/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6208 - val_loss: 0.5848
# Epoch 9/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6118 - val_loss: 0.5743
# Epoch 10/600
# ...

# %%
pd.DataFrame(model.history.history).plot()
# Out:
# <Axes: >

# %%
#helps overfitting problem 
# you can set the dropout rate 
from tensorflow.keras.layers import Dropout

# %%
model = Sequential() 

model.add(Dense(32,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(16,activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam',loss='binary_crossentropy')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
earlystop = EarlyStopping(monitor='val_loss',mode='min',patience=20)

# %%
model.fit(X_train,y_train,
          validation_data=(X_test,y_test),
          epochs=600, 
          callbacks=[earlystop])
# Out:
# Epoch 1/600
# 20/20 [==============================] - 2s 18ms/step - loss: 0.7080 - val_loss: 0.6740
# Epoch 2/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6883 - val_loss: 0.6621
# Epoch 3/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6788 - val_loss: 0.6535
# Epoch 4/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6793 - val_loss: 0.6541
# Epoch 5/600
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6821 - val_loss: 0.6521
# Epoch 6/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6637 - val_loss: 0.6495
# Epoch 7/600
# 20/20 [==============================] - 0s 7ms/step - loss: 0.6882 - val_loss: 0.6485
# Epoch 8/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6690 - val_loss: 0.6439
# Epoch 9/600
# 20/20 [==============================] - 0s 6ms/step - loss: 0.6700 - val_loss: 0.6411
# Epoch 10/600
# ...

# %%
pd.DataFrame(model.history.history).plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
predict = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
print(confusion_matrix(y_test,predict))
# Out:
# [[91 16]
#  [19 28]]

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       107
#            1       0.64      0.60      0.62        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.72      0.73       154
# weighted avg       0.77      0.77      0.77       154

# %% [markdown]
# ###### From above classification model we can see,accuracy of f1 score is around 77%, macro avg is 72% amd weighted avg is 76%.which is not best when compared to other models. Because other models have 79% accuracy.
